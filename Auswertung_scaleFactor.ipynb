# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

datensatz=pd.read_csv(r"C:\Users\goex1\Desktop\1 Weiterbildung Data Science\Abschlussprojekt\ScaleFactor, minNeighbors, Erkennungsrate.csv", delimiter=";")
datensatz.columns

datensatz['Erkennungsrate_Gesichter_in_%'] = pd.to_numeric(datensatz['Erkennungsrate_Gesichter_in_%'].str.replace(",", ".").str.strip(), errors="coerce")
datensatz['scaleFactor'] = pd.to_numeric(datensatz['scaleFactor'].str.replace(",", ".").str.strip(), errors="coerce")

colors={3:"green", 4:"blue",5:"red"}

sns.lineplot(data=datensatz,x="scaleFactor", y="Erkennungsrate_Gesichter_in_%", hue="minNeighbors", palette=colors, linewidth=1)
# Out:
# c:\Users\goex1\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\goex1\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\goex1\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...
